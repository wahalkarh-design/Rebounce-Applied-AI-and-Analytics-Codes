# %% [markdown]
# <a href="https://colab.research.google.com/github/wahalkarh-design/Rebounce-Applied-AI-and-Analytics-Codes/blob/main/Python_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
("MP1 starting")
# Out:
# 'MP1 starting'

# %%
name="Himali"
city="Pune"
year_of_birth ="1999"
age="27"

# %%
print("Hi,","I'm", name,"from,",city,"This year I turn",age)
# Out:
# Hi, I'm Himali from, Pune This year I turn 27

# %%
INR_Value= 75000
Exchange_Rate_1INR=1.75
Yen = INR_Value *Exchange_Rate_1INR
print("Yen to receive:", int(Yen))
# Out:
# Yen to receive: 131250

# %%
bread=40
milk=65.50
eggs=120

Total=(bread+milk+eggs)
Average_price=(bread+milk+eggs)/3

print("Total=", int(Total))
print("Average price=",int(Average_price))
# Out:
# Total= 225
# Average price= 75

# %%
Number= 99
is_even = False


print("Is 99 even?" ,bool(is_even))
# Out:
# Is 99 even? False

# %%
Password = "Goodmorning@2026"
Length_ok= True
Contains_at= True
Strong = True

print("Password:","Goodmorning@2026")
print("Length ok:",bool(Length_ok))
print("Contains @ :",bool(Contains_at))
print("Strong:",bool(Strong))
# Out:
# Password: Goodmorning@2026
# Length ok: True
# Contains @ : True
# Strong: True

# %%
Total_attendeens=["Prajakta","Gajanan","Pratik","Sanika","Chakuli","Shreedeep","Palshet","ktown"]
First= ["Prajakta"]
Last_Two=['Palshet','ktown']
First_three_alphabetically=['Chakuli','Gajanan','Prajakta']

print("Total attendeens:" ,len(Total_attendeens))
print("First:",Total_attendeens[0])
print("Last Two:",Total_attendeens[-2:]),
print("First_three_alphabetically:",First_three_alphabetically)
# Out:
# Total attendeens: 8
# First: Prajakta
# Last Two: ['Palshet', 'ktown']
# First_three_alphabetically: ['Chakuli', 'Gajanan', 'Prajakta']

# %% [markdown]
# ### ***DICTIONARY***

# %%
contact_details = {
    "Himali's Number": 1234567890,
    "Pratik's Number": 99876543213,
    "Prajakta's Number": 1234512345,
    "Gajanan's Number": 6789067890,
    "Sanika's Number": 1111111111,
}

contact_details["Surprise's Number"] = 7777777777

print(contact_details)
print("Surprise's Number:", contact_details["Surprise's Number"])
print("After Adding Surprise:",len(contact_details),"contacts")
# Out:
# {"Himali's Number": 1234567890, "Pratik's Number": 99876543213, "Prajakta's Number": 1234512345, "Gajanan's Number": 6789067890, "Sanika's Number": 1111111111, "Surprise's Number": 7777777777}
# Surprise's Number: 7777777777
# After Adding Surprise: 6 contacts

# %%
Squares= 1,4,9,25,36,48,64,72,81,100,121,144,139,196,225,256,289,324,361,400
Even_Squares= []
if Squares%2  == Even_Squares
print("Even Squares=" ,int("Even_Squares"))
# Out:
#   File "/tmp/ipykernel_1761/965801448.py", line 3
#     if Squares%2  == Even_Squares
#                                  ^
# SyntaxError: expected ':'

# %%
Products= {
     "pencil":10,
     "eraser":5 ,
     "sharpner":7,
     "pins":10,
     "bagpack":1000,
     "compass":200
}

for
